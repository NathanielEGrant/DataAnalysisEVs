# %% [markdown]
# # COGS 108 - Electric Vehicles and their impact on air pollution

# %% [markdown]
# ### Video- https://www.youtube.com/watch?v=OkVyox8kekg

# %% [markdown]
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [   ] YES - make available
# * [ X ] NO - keep private

# %% [markdown]
# # Overview

# %% [markdown]
# For our project we chose to look at the effect electric vehicles have had on the climate in the past 11 years.
#  We did so by taking analysis of electric and gasoline vehicle production, CO2 emmisions, and other factors and variables and looking at the trends of those numbers.
#  Our results show that there is strong evidence that as the amount of electric vehicles has increase in the past 11 years, they have had a positive impact on air pollution and specifically CO2 emissions in the world.

# %% [markdown]
# # Names
#
# - Andy Schade
# - Nathaniel Grant
# - Katherine Hottinger
# - Mayra Trejo
# - Nishant Jain

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# ### Has the production of electric vehicles in the last 11 years affected the amount of air pollution throughout the world?

# %% [markdown]
# ---

# %% [markdown]
# <a id='background'></a>
#
# ## Background & Prior Work

# %% [markdown]
# Internal combustion engines (ICE) vehicles emit more pollutants than just the exhaust that exits from their tailpipes as well as through fuel system evaporation and during fueling.
# Gasoline, emissions are created during the extraction of petroleum from the earth, refinement, distribution to fuel stations, and combustion in cars. These emissions are also known as upstream emissions or well-to-wheel emissions.
#  Modern ICE manufacturers have reduced their CO2 emissions; however the production process still has a detrimental effect on the environment.
#
# Direct emissions from all-electric vehicles are zero. Emissions in Electric Vehicles are produced by electric power plants, and more are produced during the extraction, processing, and distribution of the major energy sources that go into making the electricity.
#  There are upstream emissions produced during the manufacture of EV batteries. In reality, EV manufacture can be more environmentally damaging than ICE production. EVs are still the cleanest form of transportation because their entire life cycle is significantly more environmentally friendly.
# Many businesses have started using electric vehicles (EVs) as a result of rising fuel prices and a push for greener initiatives known for their high fuel efficiency, EVs might be an affordable option to lower running costs. An electric car often costs less per mile than a gasoline-powered vehicle, at around 3 cents as opposed to 10 cents.
#  Electric Vehicles are a more environmentally friendly option than gas or diesel automobiles in addition to having cheaper fuel expenses. They can lower carbon gas emissions by getting rid of exhaust. This benefit aids companies in continuing to operate sustainably and in compliance with legal requirements.
#
# Electric motors in Electric Vehicles are powered by rechargeable lithium-ion batteries, which are also used to power computers and smartphones. Electric Vehicles can be charged by
#  plugging into external power sources just like electrical devices do. In addition to being cleaner than internal combustion engines, lithium-ion batteries frequently perform better. Many have an 8–10 year guaranteed life span.
#
# Many electric charging stations are provided for the EV batteries just like gas stations. An EV's battery life determines how far it can go between charging points. Electric Vehicles do not emit Carbon dioxide which helps reduce the pollution in the air.
# There are three different Kinds of Electric vehicles.
# - Battery electric vehicles: Which is completely electric and does not need any fuel at all
# - Plug-in hybrid electric vehicles (PHEVs): This car is both electric and Fuel based. They are capable of regenerative braking and have batteries that can be charged by an external outlet. In order to increase the vehicle's range and replenish the battery, PHEVs additionally use a gas engine.
# - Hybrid electric vehicles (HEVs): Both gasoline and electricity are used to power this car as well but They are distinct from PHEVs because they exclusively use regenerative braking to recharge their batteries. When driving, these EVs use their electric motor; but, as the load or speed increases, the electric motor is supplemented by the gasoline engine.
#
# Five ways those Electric vehicles are more environmentally friendly than Gasoline vehicles.
# - EVs can produce zero tailpipe emissions.
# - Even when using fossil fuels, EVs contribute fewer emissions than ICE vehicles.
# - EV battery production can be clean.
# - ICE vehicles pollute continuously.
# - EV manufacturers use eco-friendly materials.
#
# The research team examined and contrasted four distinct datasets in order to assess the effects of the adoption of electric vehicles. Initially, they tallied the total number of Zero Emission Vehicles (ZEVs) registered in each zip code for each year between 2013 and 2019 (which includes battery electric, plug-in hybrid, and hydrogen fuel cell automobiles). They did this by obtaining ZEV data from the California Department of Motor Vehicles.
#  Also received information on zip code-level emergency department visits due to asthma from the U.S. Environmental Protection Agency air monitoring sites on nitrogen dioxide (NO2) levels, a pollutant associated with traffic. One of the long-standing health issues associated with air pollutants like NO2, which can also induce and exacerbate other respiratory disorders as well as issues with the heart, brain, and lung function, is asthma.
#
# The researchers then determined the proportion of adults with bachelor's degrees in each zip code. It is common practice to utilize educational degrees as a gauge of a neighborhood's socioeconomic standing.
#
# At the zip code level, there was a 3.2% decrease in the rate of emergency visits linked to asthma and a modest suggestive decrease in NO2 levels for every additional 20 ZEVs per 1,000 inhabitants.
# ZEVs rose from 1.4 to 14.6 per 1,000 people in the state's zip codes on average between 2013 and 2019. In zip codes with lower levels of education, ZEV adoption was noticeably lower. As an illustration, the average annual gain in ZEVs per 1,000 persons in a zip code with 17% of the population holding a bachelor's degree was 0.70 ZEVs per 1,000 people.
#
#
# References (include links):
# - 1) https://www.samsara.com/guides/how-are-electric-vehicles-better-for-the-environment
# - 2) https://keck.usc.edu/study-links-adoption-of-electric-vehicles-with-less-air-pollution-and-improved-health

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We believe that the production of electric vehicles in the past 11 years did not have a major impact on the amount of air pollution in the world but it did make a little difference. This is due of the fact that while the production of these EVs has increased, there are still a large percentage of drivers that use gas powered vehicles compared to EVs.
# We also believe that most large corporations are responsible for the pollution in the world, and drown out the amount of work EV's do in terms of air pollution.

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# - Dataset Name: Electric Cars VS Motor Cars 2010 - 2021(Worldwide)
# - Link to the dataset: https://www.kaggle.com/datasets/ilyaskaddouri/electric-cars-vs-motor-cars?resource=download
# - Number of observations: 11. (2010 - 2021)
#
#
#
# This data set is a log of different datapoints relating to the purchasing and use of EV cars as it relates to the CO2 emissions.

# %% [markdown]
# # Setup and Data Cleaning

# %% [markdown]
# The code below reads a CSV file called "Electric_Cars_VS_Motor_Cars.csv" using pandas and separates the fields using semicolons as the separator. The resulting dataframe is printed to the console.
#
# Then, a new dataframe called newTable is created by dropping four columns from the original dataframe (EV Stock BEV, EV Stock PHEV, Electricity demand BEV, and Electricity demand BHEV). These columns were decided to be uneccessary to the data analysis that we wanted to do as a group. The resulting dataframe is also printed to the console.
#
# The "Oil displacement (Million barrels per day)" column has data that is interpreted by python as a string. Inorder to change the data types to float we had to used the .strreplace method to change the commas "," to periods "." in order to be able to undergo the next functionality in te line under where we typecasted the whole column from strings to floats.
#
# The original dataframe has data on electric and motor car sales, EV stock and electricity demand, oil displacement, and CO2 emissions for BEV and PHEV, among other information. The new dataframe only includes information on EV sales, oil displacement, and CO2 emissions. The units for some of the values are given in the comments.

# %%
import pandas as pd
url = "Electric_Cars_VS_Motor_Cars.csv"
df = pd.read_csv(url, sep = ';')
df
# Out:
#     Year  EV sales BEV  EV sales PHEV  EV Stock BEV  EV Stock PHEV  \
# 0   2010          7400            380         17000            400
# 1   2011         40000           9100         55000           9500
# 2   2012         59000          61000        120000          70000
# 3   2013        110000          92000        230000         160000
# 4   2014        190000         130000        410000         300000
# 5   2015        330000         220000        730000         520000
# 6   2016        470000         290000       1200000         810000
# 7   2017        760000         420000       1900000        1200000
# 8   2018       1400000         640000       3300000        1800000
# 9   2019       1500000         580000       4800000        2400000
# 10  2020       2000000         980000       6900000        3400000
# 11  2021       4700000        1900000      11000000        5200000
#
#     Electricity demand BEV  Electricity demand BHEV  \
# ...

# %%
# drop unused columns of the table: 'EV Stock BEV', 'EV Stock PHEV', 'Electricity demand BEV', 'Electricity demand BHEV'
newTable = df.drop(columns = ['EV Stock BEV', 'EV Stock PHEV', 'Electricity demand BEV', 'Electricity demand BHEV'])

# replace the comma with a period in the "Oil displacement (Million barrels per day)" column
newTable["Oil displacement (Million barrels per day)"] = newTable["Oil displacement (Million barrels per day)"].str.replace(",", ".")

# convert the "Oil displacement (Million barrels per day)" column to float and round to the nearest integer
newTable["Oil displacement (Million barrels per day)"] = newTable["Oil displacement (Million barrels per day)"].astype(float)

newTable
# Out:
#     Year  EV sales BEV  EV sales PHEV  \
# 0   2010          7400            380
# 1   2011         40000           9100
# 2   2012         59000          61000
# 3   2013        110000          92000
# 4   2014        190000         130000
# 5   2015        330000         220000
# 6   2016        470000         290000
# 7   2017        760000         420000
# 8   2018       1400000         640000
# 9   2019       1500000         580000
# 10  2020       2000000         980000
# 11  2021       4700000        1900000
#
#     Oil displacement (Million barrels per day)  \
# 0                                        0.001
# 1                                        0.002
# 2                                        0.003
# 3                                        0.008
# 4                                        0.014
# 5                                        0.020
# 6                                        0.030
# 7                                        0.050
# ...

# %% [markdown]
# This table shows the EV car sales and Average CO2 emissions per year from 2010 to 2021.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Data Analysis & Results

# %% [markdown]
# Include cells that describe the steps in your data analysis.

# %% [markdown]
# ## Analysis To Conduct

# %% [markdown]
# To answer the research question "Has the production of electric vehicles in the last 11 years affected the amount of air pollution in the United States?", we can conduct the following tests on the data set:
#
# 1. Correlation Analysis: We can conduct a correlation analysis to determine whether there is a relationship between the production of electric vehicles and the amount of oil displacement (in million barrels per day) in the United States. A negative correlation would suggest that the production of electric vehicles is associated with a decrease in oil displacement, which could lead to a reduction in air pollution.
# ---
# 2. Regression Analysis: We can perform a regression analysis to determine the effect of the production of electric vehicles on the amount of oil displacement in the United States. By controlling for other variables such as the production of conventional vehicles and changes in driving patterns, we can estimate the impact of electric vehicle production on air pollution.
# ---
# 3. CO2 Emission Analysis: We can compare the average CO2 emissions per BEV produced and the average CO2 emissions per PHEV produced over the years to see if there is a trend of decreasing CO2 emissions. This would suggest that the production of electric vehicles is associated with a decrease in greenhouse gas emissions, which would reduce air pollution.
# ---
# 4. Production Trends: We can look at the production trends of electric vehicles over the years and compare it with the total number of motor cars produced per year. This would give us an indication of whether electric vehicles are gaining popularity, and if so, what percentage of the total motor cars produced they represent. If the production of electric vehicles is increasing over time, it could suggest that they are becoming a more significant contributor to reducing air pollution.
# ---
# By conducting these tests, we hopefully can determine whether the production of electric vehicles has had an impact on air pollution in the United States over the last 11 years.

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### Test 1 - Correlation Analysis

# %% [markdown]
# To conduct a correlation analysis using Python code, we first need to import the necessary libraries:

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = newTable

# %% [markdown]
# Next, we can calculate the correlation coefficient between the two variables of interest (EV sales and oil displacement) using the corr() function in pandas:

# %%
correlation_coefficient = df['EV sales BEV'].corr(df['Oil displacement (Million barrels per day)'])

# %% [markdown]
# Now lets print the correlation coefficient:

# %%
print(correlation_coefficient)
# Out:
# 0.9642283371221274

# %% [markdown]
# The output will be a value between -1 and 1, where a negative value indicates a negative correlation, and a positive value indicates a positive correlation. A value of 0 indicates no correlation.
#
# To visualize the correlation, we can create a scatter plot using seaborn:

# %%
sns.scatterplot(x='EV sales BEV', y='Oil displacement (Million barrels per day)', data=df)
plt.show()

# %% [markdown]
#  If there is a negative correlation, we should see a downward trend in the data points on the scatter plot.

# %% [markdown]
# If we want to see the correlation between multiple variables, we can create a correlation matrix using seaborn:

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %% [markdown]
# This will create a heatmap with the correlation coefficients between all pairs of variables in the dataframe.

# %% [markdown]
# ### Test 1 - Conclusions

# %% [markdown]
# A correlation coefficient of .964 suggests a very strong positive correlation between the production of electric vehicles and the amount of oil displacement (in million barrels per day) in the United States. This means that as the production of electric vehicles increases, the amount of oil displacement also tends to increase.
#
# It is important to note that correlation does not necessarily imply causation. While the strong positive correlation suggests that there may be a relationship between the two variables, further research is needed to establish causality and to determine whether the production of electric vehicles is indeed leading to a reduction in air pollution through a decrease in oil displacement.

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### Test 2 - Regression Analysis

# %% [markdown]
# To perform a regression analysis, we can use the statsmodels library in Python. Here are the steps to perform a multiple linear regression analysis:

# %%
#import required libraries
import statsmodels.api as sm

# %% [markdown]
# Next, we need to define the independent and dependent variables:

# %%
X = df[['EV sales BEV', 'EV sales PHEV', 'Total Motor cars production per year']]
y = df['Oil displacement (Million barrels per day)']

# %% [markdown]
# Here, we are using three independent variables - the number of BEV sales, the number of PHEV sales, and the total motor car production per year. We are using oil displacement as the dependent variable.

# %%
# add the constant term to the indep variables

X = sm.add_constant(X)

# and fit the mult linear regression model

model = sm.OLS(y, X).fit()
# Out:
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   x = pd.concat(x[::order], 1)

# %% [markdown]
# In the last step we built the multiple linear regression model and now we need to print it. We will do this by using the .summary() functionality.
#
# This will output a summary table of the regression analysis, which includes information such as the coefficients, standard errors, t-values, and p-values for each independent variable.

# %%
print(model.summary())
# Out:
#                                         OLS Regression Results
# ...
# Dep. Variable:     Oil displacement (Million barrels per day)   R-squared:                       0.939
# Model:                                                    OLS   Adj. R-squared:                  0.917
# Method:                                         Least Squares   F-statistic:                     41.40
# Date:                                        Tue, 21 Mar 2023   Prob (F-statistic):           3.22e-05
# Time:                                                22:04:03   Log-Likelihood:                 32.095
# No. Observations:                                          12   AIC:                            -56.19
# Df Residuals:                                               8   BIC:                            -54.25
# Df Model:                                                   3
# Covariance Type:                                    nonrobust
# ...

# %% [markdown]
# ### Test 2 - Conclusions

# %% [markdown]
# Based on the given regression analysis results, we can make the following conclusions:

# %% [markdown]
# 1. The model is statistically significant as the F-statistic has a low p-value of 3.22e-05, indicating that the independent variables are jointly significant in explaining the dependent variable.
#
# 2. The R-squared value of 0.939 indicates that the independent variables in the model explain 93.9% of the variation in the dependent variable, which is a high percentage.
# - However, the adjusted R-squared value of 0.917 suggests that the model probably has some overfitting issues.
#
# 3. The coefficients of the independent variables are all very small, with the highest being 1.237e-07. This suggests that the impact of electric vehicle production on oil displacement is negligible.
#
# 4. None of the independent variables are statistically significant as their p-values are all greater than 0.05, indicating that they do not have a significant effect on the dependent variable.

# %% [markdown]
# In summary, the regression analysis suggests that there is no significant impact of electric vehicle production on oil displacement in the United States after controlling for other variables. The model may have some overfitting issues, which could limit its usefulness in making accurate predictions.

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### Test 3 - CO2 Emission Analysis:

# %% [markdown]
# Necessary libraries are already imported.
#
# We will be using pandas and matplotlib for this test.
#
# We will also be setting df to a different table df1 inorder to manipulate df1.

# %%
#import pandas as pd
#import matplotlib.pyplot as plt
df1 = df
df1
# Out:
#     Year  EV sales BEV  EV sales PHEV  \
# 0   2010          7400            380
# 1   2011         40000           9100
# 2   2012         59000          61000
# 3   2013        110000          92000
# 4   2014        190000         130000
# 5   2015        330000         220000
# 6   2016        470000         290000
# 7   2017        760000         420000
# 8   2018       1400000         640000
# 9   2019       1500000         580000
# 10  2020       2000000         980000
# 11  2021       4700000        1900000
#
#     Oil displacement (Million barrels per day)  \
# 0                                        0.001
# 1                                        0.002
# 2                                        0.003
# 3                                        0.008
# 4                                        0.014
# 5                                        0.020
# 6                                        0.030
# 7                                        0.050
# ...

# %% [markdown]
# Next, we want to calculate the average CO2 emissions per BEV produced and per PHEV produced for each year:

# %%
# average CO2 emissions per BEV produced
df1['Avg CO2 BEV'] = df1['Average CO2 emission per BEV produced (Kg CO2e)'] / df1['EV sales BEV']
# average CO2 emissions per PHEV produced
df1['Avg CO2 PHEV'] = df1['Average CO2 emission per PHEV produced (Kg CO2e)'] / df1['EV sales PHEV']

# %% [markdown]
# Now lets take a look at what df1 looks like:
#
# Scroll to the right to see the new columns: Avg CO2 BEV	and Avg CO2 PHEV

# %%
df1
# Out:
#     Year  EV sales BEV  EV sales PHEV  \
# 0   2010          7400            380
# 1   2011         40000           9100
# 2   2012         59000          61000
# 3   2013        110000          92000
# 4   2014        190000         130000
# 5   2015        330000         220000
# 6   2016        470000         290000
# 7   2017        760000         420000
# 8   2018       1400000         640000
# 9   2019       1500000         580000
# 10  2020       2000000         980000
# 11  2021       4700000        1900000
#
#     Oil displacement (Million barrels per day)  \
# 0                                        0.001
# 1                                        0.002
# 2                                        0.003
# 3                                        0.008
# 4                                        0.014
# 5                                        0.020
# 6                                        0.030
# 7                                        0.050
# ...

# %% [markdown]
# Then, we want to use the average CO2 emissions per BEV produced and per PHEV produced for each year to plot the trends of the average CO2 emissions per BEV produced and per PHEV produced over the years:

# %%
plt.plot(df['Year'], df['Avg CO2 BEV'], label='BEV')
plt.plot(df['Year'], df['Avg CO2 PHEV'], label='PHEV')
plt.xlabel('Year')
plt.ylabel('Average CO2 Emission per Car (Kg CO2e)')
plt.title('Trends in Average CO2 Emissions per Car Produced')
plt.legend()
plt.show()

# %% [markdown]
# Finally, we need to analyze the trends in the graph to draw a conclusion.
#
# If the trend lines for both BEV and PHEV show a consistent decrease in CO2 emissions over the years, it suggests that the production of electric vehicles is associated with a decrease in greenhouse gas emissions, which would reduce air pollution.

# %% [markdown]
# ### Test 3 - Conclusions:

# %% [markdown]
# By analyzing the trends in the graph of average CO2 emissions per BEV produced and per PHEV produced, it appears that there is a slight decrease in CO2 emissions over the years.
#
# While the trend is not very significant, it suggests that the production of electric vehicles may be contributing to reducing greenhouse gas emissions and air pollution.
#
# However, further analysis and research would be needed to confirm this trend and its significance.

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### Test 4 - Production Trends:

# %% [markdown]
# Necessary libraries are already imported.
#
# We will be using pandas and matplotlib for this test.
#
# We will also be setting df to a different table df2 inorder to manipulate df2.

# %%
#import pandas as pd
#import matplotlib.pyplot as plt
df2 = df
df2
# Out:
#     Year  EV sales BEV  EV sales PHEV  \
# 0   2010          7400            380
# 1   2011         40000           9100
# 2   2012         59000          61000
# 3   2013        110000          92000
# 4   2014        190000         130000
# 5   2015        330000         220000
# 6   2016        470000         290000
# 7   2017        760000         420000
# 8   2018       1400000         640000
# 9   2019       1500000         580000
# 10  2020       2000000         980000
# 11  2021       4700000        1900000
#
#     Oil displacement (Million barrels per day)  \
# 0                                        0.001
# 1                                        0.002
# 2                                        0.003
# 3                                        0.008
# 4                                        0.014
# 5                                        0.020
# 6                                        0.030
# 7                                        0.050
# ...

# %% [markdown]
# In order to perfom the production trends analysis we should create a new dataframe with the columns 'Year', 'EV sales BEV', and 'Total Motor cars production per year'.

# %%
df2 = df2[['Year', 'EV sales BEV', 'Total Motor cars production per year']]

# %% [markdown]
# Next we add a new column to the dataframe, 'EV percentage', which calculates the percentage of electric vehicles sold compared to the total number of motor cars produced per year.

# %%
df2['EV percentage'] = df2['EV sales BEV'] / df2['Total Motor cars production per year'] * 100

# %% [markdown]
# Finally in order to analyize the production trends we want to plot the production trends of electric vehicles against the total number of motor cars produced per year.

# %%
plt.plot(df2['Year'], df2['Total Motor cars production per year'], label='Total Motor cars production per year')
plt.plot(df2['Year'], df2['EV sales BEV'], label='EV sales BEV')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Number of vehicles by 10s of millions')
plt.title('Production Trends')
plt.show()

# %% [markdown]
# The plot above shows the production trends of electric vehicles compared to the total number of motor cars produced per year.

# %% [markdown]
# ### Test 4 - Conclussions:

# %% [markdown]
# Based on the plot, we can observe that the production of electric vehicles has been increasing over the years.
#
# - In 2010, the percentage of electric vehicles sold was less than 1% of the total motor cars produced.
# - However, by 2021, this percentage had increased to more than 10%.
#
# This indicates that electric vehicles are becoming increasingly popular and are gaining traction in the market. Additionally, the increase in electric vehicle production suggests that they may be becoming a more significant contributor to reducing air pollution.

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# There should be no privacy issues related to our question, dataset, and analysis due to the public information we will be collecting from Kaggle. All the data from Kaggle can not be traced to an individual. The data set that we gathered from Kaggle is an unbiased source. If the data are not already anonymized to protect individuals’ privacy,
# we would have to anonymize the data before our data analysis and findings. However, our datasets are limited and only focus on the location (city, postal code) and car information. Other information will be considered in our research including socioeconomic standing but will not violate their privacy. We are not targeting any groups or
# exposing potential inequalities that are not already public.
#
# Regarding potential biases in our datasets, our research will be focusing on the Earth's data as a whole. This can be an issue as some countries are slow to the production of EVS, and some have other environmental factors to worry about.
# Another potential bias from the data is the people who did not participate in the research or were not counted. However, in general, we believe that our analysis can have accurate enough results to ignore some of these other factors. We will note these biases throughout the project and discuss their potential impacts on our research findings and visualizations.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# In summary, our team decided to look at the effect the production of electric vehicles have had on the climate in the U.s. in the past 11 years. To do this, we found a dataset which included data such as the number of electric vehicles produced or the amount of CO2 emissions produced.
#  From there we had to clean up our data so that we were able to have electric car sales, average CO2 emissions per year, and oil displacement all lined up. After our data was cleaned we used Correlation Analysis and Regression Analysis to find trends and patterns within our dataset.
#  Our first analysis was looking to find correlation between EV sales and oil displacement, using pandas functions and a scatterplot. Our analysis showed that the correlation coefficient was very high, which means that as the production of electric vehicles increases, oil displacement increased.
#  However, as correlation does not equal causation, further testing would need to be done in order to prove this theory. Then, using regression analysis, we attempted to validate that idea, using our car sales and oil displacement variables. The regression model showed that electric vehicles actually do not have a significant impact on oil displacement, however overfitting could have lowered the accuracy of the test.
#  We then attempted to find trends in our data by creating graphs, the first of which was a plot showcasing the average CO2 emission per car over the years. While this plot may be limiting due to the lack of outside factors, it showcased that we have reached a slight decrease in CO2 emissions over the years. Another trend we wanted to look into was the amount of electric vehicles there are on the streets versus motor cars. We graphed these numbers, and found that from 2010 to 2021, the percentage of EVs sold jumped from less than one percent to more than ten. From these results, we concluded that while more EVs have been produced and sold, climate change in terms of CO2 emissions has overall been unaffected by these sales.
#
#  A limitation of our research might be the lack of in depth variables, such as other factors that might contribute to oil displacement in the U.S. or CO2 emissions. Because of this we might not be able to see correlation between variables and these climate change variables, and therefore some of our analysis could be missing important variables. Another limitation might be the scope of our project, as our dataset encompasses the entire world. Because our dataset is so large, we could not generalize our data to specifc regions as percentages of vehicle production and climate change elements can be very different depending on the region.

# %% [markdown]
# # Team Contributions

# %% [markdown]
# - **Andy Schade**
#
#   -Data Cleaning, Data Visualizations, Data Analysis and Results
# - **Nathaniel Grant**
#
#   -Helped create Research Question and Hypothesis, helped create Conclusion & Final video, Final Check
# - **Katherine Hottinger**
#
#   -Background and Prior Work, Data gathering, helped create Final video, Final Check
# - **Mayra Trejo**
#
#   -Ethics and Privacy, helped create Conclusion, Final Check
# - **Nishant Jain**
#
#   -Background and Prior Work, created Research Question, helped with Hypothesis, Statistical Analysis
# ### Video Submission Location is at Top of the Report
